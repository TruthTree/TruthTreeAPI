# %%
import pandas as pd

# %%
csv_data = pd.read_csv(
    './assets/StateData.csv',
    error_bad_lines=False)
df = pd.DataFrame(csv_data)

# %%
df.iloc[0]['SurveyYr']
# Out:
# 16

# %%
columns = ['Name', 'FIPS_Code_State']
df_state = pd.DataFrame(columns=columns)

# %%
for i in range(51):
    current = df.iloc[i]
    df_state.at[i, 'Name'] = current['Name']
    df_state.at[i, 'FIPS_Code_State'] = current['FIPS_Code_State']

# %%
for year in range(2007, 2017):
    for state in df_state['Name'].unique():
        df_current = df[(df['Year4']==year) & (df['Name']==state)]
        print(df_current)
        break
#         df_state_population['State_id'] = df['FIPS_Code_State'].fillna(0)
#         df_state_population['Population'] = df['Population'].fillna(0)
#         df_state_population['Year'] = df['Year4'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/opioid_study-oZUPmX6j/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year4'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-92d2f2684a7f> in <module>
# ...

# %%
df.columns.values.tolist()
# Out:
# ['SurveyYr',
#  'Year4',
#  'YearofData',
#  'ID',
#  'IDChanged',
#  'State_Code',
#  'Type_Code',
#  'County',
#  'Name',
#  'FIPS_Code_State',
#  'FIPS_County',
#  'FIPS_Place',
#  'FYEndDate',
#  'YearPop',
#  'SchLevCode',
#  'Population',
#  'FunctionCode',
#  'Enrollment',
#  'Total_Revenue',
#  'Total_Rev_Own_Sources',
#  'General_Revenue',
#  'Gen_Rev_Own_Sources',
#  'Total_Taxes',
#  'Property_Tax',
#  'Tot_Sales___Gr_Rec_Tax',
#  'Total_Gen_Sales_Tax',
#  'Total_Select_Sales_Tax',
#  'Alcoholic_Beverage_Tax',
#  'Amusement_Tax',
#  'Insurance_Premium_Tax',
#  'Motor_Fuels_Tax',
#  'Pari_mutuels_Tax',
#  'Public_Utility_Tax',
#  'Tobacco_Tax',
#  'Other_Select_Sales_Tax',
#  'Total_License_Taxes',
#  'Alcoholic_Beverage_Lic',
#  'Amusement_License',
#  'Corporation_License',
#  'Hunting___Fishing_License',
#  'Motor_Vehicle_License',
#  'Motor_Veh_Oper_License',
#  'Motor_Vehicle_License_Total',
#  'Public_Utility_License',
#  'Occup_and_Bus_Lic_NEC',
# ...
